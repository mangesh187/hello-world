# %% [markdown]
# <a href="https://colab.research.google.com/github/mangesh187/hello-world/blob/master/day7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib as plt

# %%
import seaborn as se

# %%
import pandas as pd

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-d972124a-7fbd-422e-8c1a-ee53c818748f" name="files[]" multiple disabled />
#      <output id="result-d972124a-7fbd-422e-8c1a-ee53c818748f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving WorldHappiness2018_Data.csv to WorldHappiness2018_Data.csv
# ...

# %%
df=pd.read_csv("WorldHappiness2018_Data.csv")

# %%
df
# Out:
#      Rank                   Country  ...  Perceptions_Of_Corruption  Residual
# 0       1                   Finland  ...                      0.393     2.988
# 1       2                    Norway  ...                      0.340     2.723
# 2       3                   Denmark  ...                      0.408     2.779
# 3       4                   Iceland  ...                      0.138     2.564
# 4       5               Switzerland  ...                      0.357     2.675
# ..    ...                       ...  ...                        ...       ...
# 151   152                     Yemen  ...                      0.064     1.170
# 152   153                  Tanzania  ...                      0.097     0.725
# 153   154               South Sudan  ...                      0.106     1.796
# 154   155  Central African Republic  ...                      0.038     2.526
# 155   156                   Burundi  ...                      0.076     1.828
#
# [156 rows x 10 columns]

# %%
df.head()
# Out:
#    Rank      Country  Score  ...  Generosity  Perceptions_Of_Corruption  Residual
# 0     1      Finland  7.632  ...       0.192                      0.393     2.988
# 1     2       Norway  7.594  ...       0.286                      0.340     2.723
# 2     3      Denmark  7.555  ...       0.284                      0.408     2.779
# 3     4      Iceland  7.495  ...       0.353                      0.138     2.564
# 4     5  Switzerland  7.487  ...       0.256                      0.357     2.675
#
# [5 rows x 10 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df['Rank'],df['Score'])
plt.show()

# %%
gdp=df['GDP_Per_Capita']

# %%
lyf=df['Healthy_Life_Expectancy']

# %%
plt.plot(df['Rank'],lyf)

# %%
plt.plot(df['Rank'],lyf)
plt.plot(df['Rank'],gdp)
plt.title("Rank vs gdp and lyf")
plt.show()

# %%
plt.plot(df['Rank'],lyf)
plt.plot(df['Rank'],gdp)
plt.title("Rank vs gdp and lyf")
plt.xlabel("Rank")
plt.show()

# %%
plt.plot(df['Rank'],lyf,"green")
plt.plot(df['Rank'],gdp,"red")
plt.title("Rank vs gdp and lyf")
plt.xlabel("Rank")
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plt.plot(df['Rank'],lyf,color ="pink")
plt.plot(df['Rank'],gdp,color ="red")
plt.title("Rank vs gdp and lyf")
plt.xlabel("Rank")
plt.legend('rank,gdp')

# %%
plt.plot(df['Rank'],lyf,color ="orange",label='Rank')
plt.plot(df['Rank'],gdp,color ="red",label ='GDP')
plt.title("Rank vs gdp and lyf")
plt.xlabel("Rank")
plt.legend()
plt.show()

# %%
plt.plot(df['Rank'],lyf,color ="orange",label='Life')
plt.plot(df['Rank'],gdp,color ="red",label ='GDP')
plt.title("Rank vs gdp and lyf")
plt.xlabel("Rank")
plt.legend(loc='lower left')
plt.show()

# %%
scored=plt.hist(df['Score'])
#plt.plot(df['Score'],lyf,color ="orange",label='Life')
#plt.plot(df['Rank'],gdp,color ="red",label ='GDP')
#plt.title("Rank vs gdp and lyf")
#plt.xlabel("Rank")
#plt.legend(loc='lower left')
#plt.show()

# %%
socredd=plt.hist(df['Score'],edgecolor='black',linewidth='2.5',label='Score',color='red')

plt.legend()

# %%
score=df['Score']

# %%
Sc=score.apply(int)

# %%
print(Sc)
# Out:
# 0      7
# 1      7
# 2      7
# 3      7
# 4      7
#       ..
# 151    3
# 152    3
# 153    3
# 154    3
# 155    2
# Name: Score, Length: 156, dtype: int64

# %%
counts=Sc.value_counts()

# %%
Sc.unique()
# Out:
# array([7, 6, 5, 4, 3, 2])

# %%
print(counts.index)
# Out:
# Int64Index([5, 4, 6, 3, 7, 2], dtype='int64')

# %%
plt.bar(Sc.index,Sc)
# Out:
# <BarContainer object of 156 artists>

# %%
plt.bar(counts.index,counts)
# Out:
# <BarContainer object of 6 artists>

# %%
plt.bar(counts.index,counts,color='orange',label='Score')
plt.title('Score')
plt.legend(loc='upper left')

# %%
plt.bar(counts.index,counts,color='orange',label='Score')
plt.title('Score')
plt.legend(loc='upper left')

# %%
plt.hist(df['Score'])

# %%
#plt.hist(df['Score'],gdp,color ="orange",label='Life')
plt.scatter(df['Score'],gdp,edgecolor='black',color ="red",label ='GDP')
plt.title("Rank vs gdp and lyf")
plt.legend(loc='lower left')
plt.show()

# %%
print(plt.boxplot(score))
# Out:
# {'whiskers': [<matplotlib.lines.Line2D object at 0x7f960a2dbf60>, <matplotlib.lines.Line2D object at 0x7f960a26b2e8>], 'caps': [<matplotlib.lines.Line2D object at 0x7f960a26b630>, <matplotlib.lines.Line2D object at 0x7f960a26b978>], 'boxes': [<matplotlib.lines.Line2D object at 0x7f960a2dbc50>], 'medians': [<matplotlib.lines.Line2D object at 0x7f960a26bcc0>], 'fliers': [<matplotlib.lines.Line2D object at 0x7f960a274048>], 'means': []}

# %%
plt.boxplot(df['Score'])
plt.boxplot(df['Healthy_Life_Expectancy'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f960a1c4160>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f960a1d8160>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f960a1d8b38>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f960a1d87f0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f960a1d0a90>,
#   <matplotlib.lines.Line2D at 0x7f960a1d0dd8>]}

# %%
df
# Out:
#      Rank                   Country  ...  Perceptions_Of_Corruption  Residual
# 0       1                   Finland  ...                      0.393     2.988
# 1       2                    Norway  ...                      0.340     2.723
# 2       3                   Denmark  ...                      0.408     2.779
# 3       4                   Iceland  ...                      0.138     2.564
# 4       5               Switzerland  ...                      0.357     2.675
# ..    ...                       ...  ...                        ...       ...
# 151   152                     Yemen  ...                      0.064     1.170
# 152   153                  Tanzania  ...                      0.097     0.725
# 153   154               South Sudan  ...                      0.106     1.796
# 154   155  Central African Republic  ...                      0.038     2.526
# 155   156                   Burundi  ...                      0.076     1.828
#
# [156 rows x 10 columns]

# %%
import numpy as np

# %%
b=np.random.randint(1,100,size=[12,13])
print(b)
# Out:
# [[30 97 23 83 93 76 28 84 79 39 77 96 60]
#  [34 31 79 76 50 63 35 96 69  1 70 52 92]
#  [28 12 78 54 23  1 30 59 46 94 73 41 24]
#  [ 3 43 63 87 59 39 70  6 76 19 91  9 61]
#  [38 10 89 25 92 51 14 56 37 18 42 73 33]
#  [81 55  7 99 32 66 75 76 59 24 64 87 87]
#  [90 32 67 38 95 18 23 40 68 70 66 41 88]
#  [40 63 32 62 97 63 51 36 69 75 52 96 15]
#  [59 96 25 28  6 35 66 49 41  7 84 41 93]
#  [63 32 75 49 22 83 82 77 18 51 82  2 46]
#  [26 45 57 13 90 21 50 14 96 42 15 49 63]
#  [73 87 44 19 40 60 93 89 27 58 15 93 64]]

# %%
sns.heatmap(b)

# %%
import seaborn as sns

# %%
fh=sns.heatmap(b,linewidths=1.5)

# %%
b=np.random.randint(1,100,size=[3,3])
print(b)
fg1=sns.heatmap(b,linewidths=1.5)
# Out:
# [[74 24 10]
#  [ 8 25 84]
#  [48 17 98]]

# %%
df.columns
# Out:
# Index(['Rank', 'Country', 'Score', 'GDP_Per_Capita', 'Social_Support',
#        'Healthy_Life_Expectancy', 'Freedom_To_Make_Life_Choices', 'Generosity',
#        'Perceptions_Of_Corruption', 'Residual'],
#       dtype='object')

# %%
sns.heatmap(df[['Score', 'GDP_Per_Capita','Residual']])

# %%
df1=(lyf,gdp)

# %%
df1
# Out:
# (0      0.874
#  1      0.861
#  2      0.868
#  3      0.914
#  4      0.927
#         ...
#  151    0.343
#  152    0.381
#  153    0.177
#  154    0.010
#  155    0.145
#  Name: Healthy_Life_Expectancy, Length: 156, dtype: float64, 0      1.305
#  1      1.456
#  2      1.351
#  3      1.343
#  4      1.420
#         ...
#  151    0.442
#  152    0.455
#  153    0.337
#  154    0.024
#  155    0.091
#  Name: GDP_Per_Capita, Length: 156, dtype: float64)

# %%
sns.heatmap(df1)

# %%
df2=(df[['Rank', 'Country', 'Score', 'GDP_Per_Capita', 'Social_Support',
       'Healthy_Life_Expectancy', 'Freedom_To_Make_Life_Choices', 'Generosity',
       'Perceptions_Of_Corruption', 'Residual']])

# %%
df3=df2.corr()

# %%
sns.heatmap(df3)

# %%
sns.set(style="whitegrid")
tips=sns.load_dataset("tips")
ax=sns.violinplot(x=tips["total_bill"])

# %%
tips=sns.load_dataset("tips")
print(tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.set(style="whitegrid")
tips=sns.load_dataset("tips")
ax=sns.violinplot(x=tips["total_bill"])

# %%
ax=sns.violinplot(x=tips["total_bill"])
print(ax)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
ax=sns.violinplot(x="day",y="total_bill",data=tips)

# %%
ax=sns.violinplot(x="Rank",y="Score",data=df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-203-0fabd8ef1055> in <module>()
# ----> 1 ax=sns.violinplot(x="Rank",y="counts",data=df)
#
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py in violinplot(x, y, hue, data, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, dodge, orient, linewidth, color, palette, saturation, ax, **kwargs)
#    2385                              bw, cut, scale, scale_hue, gridsize,
#    2386                              width, inner, split, dodge, orient, linewidth,
# -> 2387                              color, palette, saturation)
#    2388
#    2389     if ax is None:
#
# ...

# %%
tips['day'].unique()
# Out:
# [Sun, Sat, Thur, Fri]
# Categories (4, object): [Sun, Sat, Thur, Fri]

# %%
ax=sns.violinplot(x='day',y="total_bill",data=tips)

# %%
ax=sns.violinplot(x="day",y="total_bill",hue="smoker",data=tips,palette="muted")

# %%
x=sns.violinplot(x="day",y="total_bill",hue="smoker",data=tips)

# %%
df
# Out:
#      Rank                   Country  ...  Perceptions_Of_Corruption  Residual
# 0       1                   Finland  ...                      0.393     2.988
# 1       2                    Norway  ...                      0.340     2.723
# 2       3                   Denmark  ...                      0.408     2.779
# 3       4                   Iceland  ...                      0.138     2.564
# 4       5               Switzerland  ...                      0.357     2.675
# ..    ...                       ...  ...                        ...       ...
# 151   152                     Yemen  ...                      0.064     1.170
# 152   153                  Tanzania  ...                      0.097     0.725
# 153   154               South Sudan  ...                      0.106     1.796
# 154   155  Central African Republic  ...                      0.038     2.526
# 155   156                   Burundi  ...                      0.076     1.828
#
# [156 rows x 10 columns]

# %%
d=df['Country'].unique()
d
# Out:
# array(['Finland', 'Norway', 'Denmark', 'Iceland', 'Switzerland',
#        'Netherlands', 'Canada', 'New Zealand', 'Sweden', 'Australia',
#        'Israel', 'Austria', 'Costa Rica', 'Ireland', 'Germany', 'Belgium',
#        'Luxembourg', 'United States', 'United Kingdom',
#        'United Arab Emirates', 'Czech Republic', 'Malta', 'France',
#        'Mexico', 'Chile', 'Taiwan', 'Panama', 'Brazil', 'Argentina',
#        'Guatemala', 'Uruguay', 'Qatar', 'Saudi Arabia', 'Singapore',
#        'Malaysia', 'Spain', 'Colombia', 'Trinidad & Tobago', 'Slovakia',
#        'El Salvador', 'Nicaragua', 'Poland', 'Bahrain', 'Uzbekistan',
#        'Kuwait', 'Thailand', 'Italy', 'Ecuador', 'Belize', 'Lithuania',
#        'Slovenia', 'Romania', 'Latvia', 'Japan', 'Mauritius', 'Jamaica',
#        'South Korea', 'Northern Cyprus', 'Russia', 'Kazakhstan', 'Cyprus',
#        'Bolivia', 'Estonia', 'Paraguay', 'Peru', 'Kosovo', 'Moldova',
# ...

# %%
df['Country'].value_counts()
# Out:
# Ivory Coast     1
# Macedonia       1
# Sierra Leone    1
# Turkmenistan    1
# Liberia         1
#                ..
# Qatar           1
# Afghanistan     1
# Madagascar      1
# Montenegro      1
# Albania         1
# Name: Country, Length: 156, dtype: int64

# %%
ab=df[(df['Country']=='Israel') | (df['Country']=='Kenya') | (df['Country']=='Angola')]

# %%
ab
# Out:
#      Rank Country  Score  ...  Generosity  Perceptions_Of_Corruption  Residual
# 10     11  Israel  7.190  ...       0.262                      0.082     2.899
# 123   124   Kenya  4.410  ...       0.352                      0.055     1.559
# 141   142  Angola  3.795  ...       0.079                      0.061     1.592
#
# [3 rows x 10 columns]

# %%
ax=sns.violinplot(x='sex',y='total_bill',hue="smoker",col="time",data="tips",kind="violin",split="true",height=4,aspect=.7)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-226-e96f1684ee9d> in <module>()
# ----> 1 ax=sns.violinplot(x='sex',y='total_bill',hue="smoker",col="time",data="tips",kind="violin",split="true",height=4,aspect=.7)
#
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py in violinplot(x, y, hue, data, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, dodge, orient, linewidth, color, palette, saturation, ax, **kwargs)
#    2385                              bw, cut, scale, scale_hue, gridsize,
#    2386                              width, inner, split, dodge, orient, linewidth,
# -> 2387                              color, palette, saturation)
#    2388
#    2389     if ax is None:
#
# ...

# %%
#nipprogess.com
#pandas real life problem
#
